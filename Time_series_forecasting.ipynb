# %% [markdown]
# **Remove Comments from the cell below if using a Google colab file**

# %%
# !pip install kaggle
! mkdir ~/.kaggle
from google.colab import files

files.upload()
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
# !kaggle competitions download -c store-sales-time-series-forecasting

# %%
! mkdir train

! unzip dataset.zip

# %% [markdown]
# Importing all necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# **Colab**
# Reading the datasets
# Remove Comments from the cell below if using a Google colab file

# %%
dfOil = pd.read_csv('oil.csv')
dfH_Events = pd.read_csv('holidays_events.csv')
dfStores = pd.read_csv('stores.csv')
dfTransactions=  pd.read_csv('transactions.csv')
df_train =pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %% [markdown]
# **Local Machine**
# Reading the datasets
# Comment out the cell below if using Google Colab

# %%
# dfOil = pd.read_csv('F://Data Science//Kaggle\Datasets//Store Sales - Time Series Forecasting//oil.csv')
# dfH_Events = pd.read_csv('F://Data Science//Kaggle\Datasets//Store Sales - Time Series Forecasting//holidays_events.csv')
# dfStores = pd.read_csv('F://Data Science//Kaggle\Datasets//Store Sales - Time Series Forecasting//stores.csv')
# dfTransactions=  pd.read_csv('F://Data Science//Kaggle\Datasets//Store Sales - Time Series Forecasting//transactions.csv')
# df_train =pd.read_csv('F://Data Science//Kaggle\Datasets//Store Sales - Time Series Forecasting//train.csv')
# df_test = pd.read_csv('F://Data Science//Kaggle\Datasets//Store Sales - Time Series Forecasting//test.csv')

# %% [markdown]
# **dfOil-Oil**

# %%
dfOil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
dfOil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
dfOil.describe()
# Out:
#         dcoilwtico
# count  1175.000000
# mean     67.714366
# std      25.630476
# min      26.190000
# 25%      46.405000
# 50%      53.190000
# 75%      95.660000
# max     110.620000

# %% [markdown]
# **dfH_Events-holiday events**

# %%
dfH_Events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale       350 non-null    object
#  3   locale_name  350 non-null    object
#  4   description  350 non-null    object
#  5   transferred  350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB

# %%
dfH_Events.head()
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
dfH_Events.describe()
# Out:
#               date     type    locale locale_name description transferred
# count          350      350       350         350         350         350
# unique         312        6         3          24         103           2
# top     2014-06-25  Holiday  National     Ecuador    Carnaval       False
# freq             4      221       174         174          10         338

# %% [markdown]
# dfStores

# %%
dfStores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
dfStores.describe()
# Out:
#        store_nbr    cluster
# count  54.000000  54.000000
# mean   27.500000   8.481481
# std    15.732133   4.693395
# min     1.000000   1.000000
# 25%    14.250000   4.000000
# 50%    27.500000   8.500000
# 75%    40.750000  13.000000
# max    54.000000  17.000000

# %%
dfStores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB

# %% [markdown]
# dfTransactions- transactions

# %%
dfTransactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
dfTransactions.describe()
# Out:
#           store_nbr  transactions
# count  83488.000000  83488.000000
# mean      26.939237   1694.602158
# std       15.608204    963.286644
# min        1.000000      5.000000
# 25%       13.000000   1046.000000
# 50%       27.000000   1393.000000
# 75%       40.000000   2079.000000
# max       54.000000   8359.000000

# %%
dfTransactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# Train

# %%
df_train.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
df_train.describe()
# Out:
#                  id     store_nbr         sales   onpromotion
# count  3.000888e+06  3.000888e+06  3.000888e+06  3.000888e+06
# mean   1.500444e+06  2.750000e+01  3.577757e+02  2.602770e+00
# std    8.662819e+05  1.558579e+01  1.101998e+03  1.221888e+01
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.502218e+05  1.400000e+01  0.000000e+00  0.000000e+00
# 50%    1.500444e+06  2.750000e+01  1.100000e+01  0.000000e+00
# 75%    2.250665e+06  4.100000e+01  1.958473e+02  0.000000e+00
# max    3.000887e+06  5.400000e+01  1.247170e+05  7.410000e+02

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.4+ MB

# %% [markdown]
# Analyzing common columns

# %%
dfs=[dfStores,dfOil]
common_cols = set(dfs[0].columns)
for df in dfs[1:]:
    common_cols = common_cols.intersection(df.columns)
print(common_cols)
# Out:
# set()

# %% [markdown]
# 1.   dfOil+train=date
# 2.   dfH_Events+train=date
# 3.   dfStores+train=store_nbr
# 4. dfTransactions+train=store_nbr,date

# %% [markdown]
# Merging

# %%
df = pd.concat([dfOil, dfH_Events, dfStores, dfTransactions, df_train], axis=0)

# %%
df.head()
# Out:
#          date  dcoilwtico type locale locale_name description transferred  \
# 0  2013-01-01         NaN  NaN    NaN         NaN         NaN         NaN
# 1  2013-01-02       93.14  NaN    NaN         NaN         NaN         NaN
# 2  2013-01-03       92.97  NaN    NaN         NaN         NaN         NaN
# 3  2013-01-04       93.12  NaN    NaN         NaN         NaN         NaN
# 4  2013-01-07       93.20  NaN    NaN         NaN         NaN         NaN
#
#    store_nbr city state  cluster  transactions  id family  sales  onpromotion
# 0        NaN  NaN   NaN      NaN           NaN NaN    NaN    NaN          NaN
# 1        NaN  NaN   NaN      NaN           NaN NaN    NaN    NaN          NaN
# 2        NaN  NaN   NaN      NaN           NaN NaN    NaN    NaN          NaN
# 3        NaN  NaN   NaN      NaN           NaN NaN    NaN    NaN          NaN
# 4        NaN  NaN   NaN      NaN           NaN NaN    NaN    NaN          NaN

# %%
df.tail()
# Out:
#                date  dcoilwtico type locale locale_name description  \
# 3000883  2017-08-15         NaN  NaN    NaN         NaN         NaN
# 3000884  2017-08-15         NaN  NaN    NaN         NaN         NaN
# 3000885  2017-08-15         NaN  NaN    NaN         NaN         NaN
# 3000886  2017-08-15         NaN  NaN    NaN         NaN         NaN
# 3000887  2017-08-15         NaN  NaN    NaN         NaN         NaN
#
#         transferred  store_nbr city state  cluster  transactions         id  \
# 3000883         NaN        9.0  NaN   NaN      NaN           NaN  3000883.0
# 3000884         NaN        9.0  NaN   NaN      NaN           NaN  3000884.0
# 3000885         NaN        9.0  NaN   NaN      NaN           NaN  3000885.0
# 3000886         NaN        9.0  NaN   NaN      NaN           NaN  3000886.0
# 3000887         NaN        9.0  NaN   NaN      NaN           NaN  3000887.0
#
#                              family     sales  onpromotion
# ...

# %%
# from functools import reduce
# dfs = [dfOil, dfH_Events, dfStores, dfTransactions, df_train]

# intersecting_cols = reduce(np.intersect1d, [df.columns for df in dfs])

# print(intersecting_cols)
# # merged_df = reduce(lambda left, right: pd.merge(left, right, on=intersecting_cols, how='outer'), dfs)
# # print(merged_df)
# Out:
# []

# %%
dfOil.isnull().sum()
# Out:
# date           0
# dcoilwtico    43
# dtype: int64

# %%
dfOil = dfOil.dropna()

# %%
dfOil.isnull().sum()
# Out:
# date          0
# dcoilwtico    0
# dtype: int64

# %%
dfOil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1175 entries, 1 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1175 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 27.5+ KB

# %%
dfH_Events.isnull().sum()
# Out:
# date           0
# type           0
# locale         0
# locale_name    0
# description    0
# transferred    0
# dtype: int64

# %%
dfStores.isnull().sum()
# Out:
# store_nbr    0
# city         0
# state        0
# type         0
# cluster      0
# dtype: int64

# %%
dfTransactions.isnull().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64

# %%
df_train.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
df_train['date'] = pd.to_datetime(df_train['date'], dayfirst=True)
df_test['date'] = pd.to_datetime(df_test['date'], dayfirst=True)
dfTransactions['date'] = pd.to_datetime(dfTransactions['date'], dayfirst=True)
dfOil['date'] = pd.to_datetime(dfOil['date'], dayfirst=True)
dfH_Events['date'] = pd.to_datetime(dfH_Events['date'], dayfirst=True)

# %%
df_train['store_nbr'].is_unique
# Out:
# False

# %%
dfStores['store_nbr'].is_unique
# Out:
# True

# %%
df_train.shape
# Out:
# (3000888, 6)

# %%
dftrainStores = pd.merge(df_train, dfStores, on='store_nbr',how='outer')
dftrainStores.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion   city      state  \
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0  Quito  Pichincha
# 1   1 2013-01-01          1   BABY CARE    0.0            0  Quito  Pichincha
# 2   2 2013-01-01          1      BEAUTY    0.0            0  Quito  Pichincha
# 3   3 2013-01-01          1   BEVERAGES    0.0            0  Quito  Pichincha
# 4   4 2013-01-01          1       BOOKS    0.0            0  Quito  Pichincha
#
#   type  cluster
# 0    D       13
# 1    D       13
# 2    D       13
# 3    D       13
# 4    D       13

# %%
dftrainStores.shape
# Out:
# (3000888, 10)

# %%
len(dftrainStores['date'].unique())
# Out:
# 1684

# %%
dfTransactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
dfTransactions['date'].is_unique
# Out:
# False

# %%
dftrainStoresTrans = pd.merge(dftrainStores, dfTransactions, on=['store_nbr', 'date'],how='outer')
dftrainStoresTrans.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion   city      state  \
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0  Quito  Pichincha
# 1   1 2013-01-01          1   BABY CARE    0.0            0  Quito  Pichincha
# 2   2 2013-01-01          1      BEAUTY    0.0            0  Quito  Pichincha
# 3   3 2013-01-01          1   BEVERAGES    0.0            0  Quito  Pichincha
# 4   4 2013-01-01          1       BOOKS    0.0            0  Quito  Pichincha
#
#   type  cluster  transactions
# 0    D       13           NaN
# 1    D       13           NaN
# 2    D       13           NaN
# 3    D       13           NaN
# 4    D       13           NaN

# %%
dftrainStoresTrans.shape
# Out:
# (3000888, 11)

# %%
dfOil.head()
# Out:
#         date  dcoilwtico
# 1 2013-01-02       93.14
# 2 2013-01-03       92.97
# 3 2013-01-04       93.12
# 4 2013-01-07       93.20
# 5 2013-01-08       93.21

# %%
dftrainStoresTransOil = pd.merge(dftrainStoresTrans, dfOil, on='date',how='outer')
dftrainStoresTransOil.head()
# Out:
#     id       date  store_nbr      family  sales  onpromotion   city  \
# 0  0.0 2013-01-01        1.0  AUTOMOTIVE    0.0          0.0  Quito
# 1  1.0 2013-01-01        1.0   BABY CARE    0.0          0.0  Quito
# 2  2.0 2013-01-01        1.0      BEAUTY    0.0          0.0  Quito
# 3  3.0 2013-01-01        1.0   BEVERAGES    0.0          0.0  Quito
# 4  4.0 2013-01-01        1.0       BOOKS    0.0          0.0  Quito
#
#        state type  cluster  transactions  dcoilwtico
# 0  Pichincha    D     13.0           NaN         NaN
# 1  Pichincha    D     13.0           NaN         NaN
# 2  Pichincha    D     13.0           NaN         NaN
# 3  Pichincha    D     13.0           NaN         NaN
# 4  Pichincha    D     13.0           NaN         NaN

# %%
dftrainStoresTransOil.shape
# Out:
# (3000903, 12)

# %%
dfH_Events.head()
# Out:
#         date     type    locale locale_name                    description  \
# 0 2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1 2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2 2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3 2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4 2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
dfAll = pd.merge(dftrainStoresTransOil, dfH_Events, on='date',how='outer')
dfAll.head()
# Out:
#     id       date  store_nbr      family  sales  onpromotion   city  \
# 0  0.0 2013-01-01        1.0  AUTOMOTIVE    0.0          0.0  Quito
# 1  1.0 2013-01-01        1.0   BABY CARE    0.0          0.0  Quito
# 2  2.0 2013-01-01        1.0      BEAUTY    0.0          0.0  Quito
# 3  3.0 2013-01-01        1.0   BEVERAGES    0.0          0.0  Quito
# 4  4.0 2013-01-01        1.0       BOOKS    0.0          0.0  Quito
#
#        state type_x  cluster  transactions  dcoilwtico   type_y    locale  \
# 0  Pichincha      D     13.0           NaN         NaN  Holiday  National
# 1  Pichincha      D     13.0           NaN         NaN  Holiday  National
# 2  Pichincha      D     13.0           NaN         NaN  Holiday  National
# 3  Pichincha      D     13.0           NaN         NaN  Holiday  National
# 4  Pichincha      D     13.0           NaN         NaN  Holiday  National
#
#   locale_name         description transferred
# 0     Ecuador  Primer dia del ano       False
# ...

# %%
dfAll.shape
# Out:
# (3054427, 17)

# %%
dfAll['id'].is_unique
# Out:
# False

# %%
df_train['id'].is_unique
# Out:
# True

# %%
dfAll['date'].is_unique
# Out:
# False

# %%
df_train.shape
# Out:
# (3000888, 6)

# %%
dfAll['id'].isna().sum()
# Out:
# 79

# %%
# exclude_columns = ['date']

# mask = dfAll.apply(lambda x: x.isnull().all() and not all(col in exclude_columns for col in x.index))

# %%
dfAll = dfAll[~mask]

print(dfAll)
# Out:
# <ipython-input-141-776f3a340641>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfAll = dfAll[~mask]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-141-776f3a340641> in <module>
# ----> 1 dfAll = dfAll[~mask]
#       2
#       3 print(dfAll)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3500         # check_bool_indexer will throw exception if Series key cannot
#    3501         # be reindexed to match DataFrame rows
# ...
